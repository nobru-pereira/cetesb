# %%
import numpy as np
import pandas as pd


#pd.read_excel(file, engine = 'pyxlsb')

file =('/home/bruno/git/cetesb-sbsr/Rede_costeiracoords_full.xlsx')
dado_pontos = pd.read_excel(file)

colstr = ['Superfície', 'Meio', 'Fundo', 'Sedimento']

dado_pontos[colstr] = dado_pontos[colstr].astype(str)

dado_pontos['fcol_sup'] = dado_pontos['Código Ponto'] + dado_pontos['Superfície']

dado_pontos['fcol_meio'] = dado_pontos['Código Ponto'] + dado_pontos['Meio']

dado_pontos['fcol_fundo'] = dado_pontos['Código Ponto'] + dado_pontos['Fundo']

dado_pontos['fcol_sed'] = dado_pontos['Código Ponto'] + dado_pontos['Sedimento']


pcols = ['fcol_sup','fcol_meio','fcol_fundo','fcol_sed']

# %%
file = '/home/bruno/git/cetesb-sbsr/cetesb_2010-202_usp.xlsx'
dado_np = pd.read_excel(file)


pontos = dado_np['Ponto'].unique()

dado_np['lat'] = np.nan
dado_np['lon'] = np.nan


for i in pontos:

	sel_row = dado_pontos[dado_pontos.apply(lambda row: row.astype(str).str.contains(i, case=False).any(), axis=1)]
	if sel_row.empty == False:

		dado_np['lat'] = np.where(dado_np['Ponto'] == i, sel_row['LAT (Sul)'], dado_np['lat'])
		dado_np['lon'] = np.where(dado_np['Ponto'] == i, sel_row['LONG (Oeste)'], dado_np['lon'])

# %%
#dado_pontos
#dado_pontos.columns

# %%
#dado_np

# %%
#open data tabela cetesb-full = tc
tc = pd.DataFrame(data=dado_np)#)

# %%
#tc.columns

# %%
dado_np
# Out:
#            Ponto       Data Unnamed: 2  Cod. Paramt.                  Paramt.  \
# 0      SSRC11031 2019-02-12   11:30:00           121      Alumínio Dissolvido
# 1      SSRC11031 2019-02-12   11:30:00        100009                  Benzeno
# 2      SSRC11031 2019-02-12   11:30:00          5002               Boro Total
# 3      SSRC11031 2019-02-12   11:30:00         48001             Cádmio Total
# 4      SSRC11031 2019-02-12   11:30:00        100082   Carbono Orgânico Total
# ...          ...        ...        ...           ...                      ...
# 68506  IGRC11033 2017-09-27   11:00:00           116  Sólido Suspenso Volátil
# 68507  IGRC11033 2017-09-27   11:00:00         10471             Sólido Total
# 68508  IGRC11033 2017-09-27   11:00:00           291    Sólidos Sedimentáveis
# 68509  IGRC11033 2017-09-27   11:00:00          2073                 Turbidez
# 68510  IGRC11031 2017-09-29   10:51:00         15410            Fósforo Total
#
#        Valor  ValorNumerico  Und. Resu. Sis. Hidrico  \
# 0        0.5           0.50  mg/L               SSRC
# 1        2.5           2.50  µg/L               SSRC
# 2       4.38           4.38  mg/L               SSRC
# 3       0.05           0.05  mg/L               SSRC
# 4       1.21           1.21  mg/L               SSRC
# ...      ...            ...   ...                ...
# 68506    100         100.00  mg/L               IGRC
# 68507  40504       40504.00  mg/L               IGRC
# 68508    0.1           0.10  mL/L               IGRC
# 68509    2.6           2.60   UNT               IGRC
# 68510   0.07           0.07  mg/L               IGRC
#
#                                  Sis. Hidrico             lat             lon
# 0      Canal de São Sebastião - Rede Costeira   23°49'16.31"S    45°24'9.09"O
# 1      Canal de São Sebastião - Rede Costeira   23°49'16.31"S    45°24'9.09"O
# 2      Canal de São Sebastião - Rede Costeira   23°49'16.31"S    45°24'9.09"O
# 3      Canal de São Sebastião - Rede Costeira   23°49'16.31"S    45°24'9.09"O
# 4      Canal de São Sebastião - Rede Costeira   23°49'16.31"S    45°24'9.09"O
# ...                                       ...             ...             ...
# 68506            Rio Itaguaré - Rede Costeira  23° 48' 14,60"  45° 58' 30,81"
# 68507            Rio Itaguaré - Rede Costeira  23° 48' 14,60"  45° 58' 30,81"
# 68508            Rio Itaguaré - Rede Costeira  23° 48' 14,60"  45° 58' 30,81"
# 68509            Rio Itaguaré - Rede Costeira  23° 48' 14,60"  45° 58' 30,81"
# 68510            Rio Itaguaré - Rede Costeira  23° 48' 14,60"  45° 58' 30,81"
#
# [68511 rows x 12 columns]

# %%
#tc_fn =tc.dropna(axis=1)

# %%
#verifica qtd de nans
tc_fn.isnull().sum()

# %%
tc.columns
# Out:
# Index(['Ponto', 'Data', 'Unnamed: 2', 'Cod. Paramt.', 'Paramt.', 'Valor',
#        'ValorNumerico', 'Und.', 'Resu. Sis. Hidrico', 'Sis. Hidrico', 'lat',
#        'lon'],
#       dtype='object')

# %%
#tc_fn.columns

# %%
dic_ct = {'Ponto': tc['Ponto'], 'lat':tc['lat'], 'lon':tc['lon'], 'Data':  tc['Data'], 'Hora':tc['Unnamed: 2'], 'Parametro': tc['Paramt.'],'valor': tc['ValorNumerico'],
     'unidade':tc['Und.'], 'local' :tc['Sis. Hidrico']}

# %%
#dic_ct

# %%
# aqui temos a tabela com todos parametros e coordenadas.
dc = pd.DataFrame(data=dic_ct)#)

# %%
dc
# Out:
#            Ponto             lat             lon       Data      Hora  \
# 0      SSRC11031   23°49'16.31"S    45°24'9.09"O 2019-02-12  11:30:00
# 1      SSRC11031   23°49'16.31"S    45°24'9.09"O 2019-02-12  11:30:00
# 2      SSRC11031   23°49'16.31"S    45°24'9.09"O 2019-02-12  11:30:00
# 3      SSRC11031   23°49'16.31"S    45°24'9.09"O 2019-02-12  11:30:00
# 4      SSRC11031   23°49'16.31"S    45°24'9.09"O 2019-02-12  11:30:00
# ...          ...             ...             ...        ...       ...
# 68506  IGRC11033  23° 48' 14,60"  45° 58' 30,81" 2017-09-27  11:00:00
# 68507  IGRC11033  23° 48' 14,60"  45° 58' 30,81" 2017-09-27  11:00:00
# 68508  IGRC11033  23° 48' 14,60"  45° 58' 30,81" 2017-09-27  11:00:00
# 68509  IGRC11033  23° 48' 14,60"  45° 58' 30,81" 2017-09-27  11:00:00
# 68510  IGRC11031  23° 48' 14,60"  45° 58' 30,81" 2017-09-29  10:51:00
#
#                      Parametro     valor unidade  \
# 0          Alumínio Dissolvido      0.50    mg/L
# 1                      Benzeno      2.50    µg/L
# 2                   Boro Total      4.38    mg/L
# 3                 Cádmio Total      0.05    mg/L
# 4       Carbono Orgânico Total      1.21    mg/L
# ...                        ...       ...     ...
# 68506  Sólido Suspenso Volátil    100.00    mg/L
# 68507             Sólido Total  40504.00    mg/L
# 68508    Sólidos Sedimentáveis      0.10    mL/L
# 68509                 Turbidez      2.60     UNT
# 68510            Fósforo Total      0.07    mg/L
#
#                                         local
# 0      Canal de São Sebastião - Rede Costeira
# 1      Canal de São Sebastião - Rede Costeira
# 2      Canal de São Sebastião - Rede Costeira
# 3      Canal de São Sebastião - Rede Costeira
# 4      Canal de São Sebastião - Rede Costeira
# ...                                       ...
# 68506            Rio Itaguaré - Rede Costeira
# 68507            Rio Itaguaré - Rede Costeira
# 68508            Rio Itaguaré - Rede Costeira
# 68509            Rio Itaguaré - Rede Costeira
# 68510            Rio Itaguaré - Rede Costeira
#
# [68511 rows x 9 columns]

# %%
## agora vamos selecionar área de interesse no dataframe - canal de sao sebastiao ccs 
ccs_wq = dc.loc[dc['local']== 'Canal de São Sebastião - Rede Costeira']

# %%
ccs_wq
# Out:
#            Ponto             lat            lon       Data      Hora  \
# 0      SSRC11031   23°49'16.31"S   45°24'9.09"O 2019-02-12  11:30:00
# 1      SSRC11031   23°49'16.31"S   45°24'9.09"O 2019-02-12  11:30:00
# 2      SSRC11031   23°49'16.31"S   45°24'9.09"O 2019-02-12  11:30:00
# 3      SSRC11031   23°49'16.31"S   45°24'9.09"O 2019-02-12  11:30:00
# 4      SSRC11031   23°49'16.31"S   45°24'9.09"O 2019-02-12  11:30:00
# ...          ...             ...            ...        ...       ...
# 67078  SSRC11031   23°49'16.31"S   45°24'9.09"O 2015-09-22  10:23:00
# 67079  SSRC11031   23°49'16.31"S   45°24'9.09"O 2015-09-22  10:23:00
# 67080  SSRC11031   23°49'16.31"S   45°24'9.09"O 2015-09-22  10:23:00
# 67081  SSRC11031   23°49'16.31"S   45°24'9.09"O 2015-09-22  10:23:00
# 67082  SSRC11031   23°49'16.31"S   45°24'9.09"O 2015-09-22  10:23:00
#
#                     Parametro  valor unidade  \
# 0         Alumínio Dissolvido   0.50    mg/L
# 1                     Benzeno   2.50    µg/L
# 2                  Boro Total   4.38    mg/L
# 3                Cádmio Total   0.05    mg/L
# 4      Carbono Orgânico Total   1.21    mg/L
# ...                       ...    ...     ...
# 67078   Sólidos Sedimentáveis   0.10    mL/L
# 67079     Temperatura da Água  23.18      ºC
# 67080       Temperatura do Ar  27.40      ºC
# 67081           Transparência   2.50       m
# 67082                Turbidez   1.00     UNT
#
#                                         local
# 0      Canal de São Sebastião - Rede Costeira
# 1      Canal de São Sebastião - Rede Costeira
# 2      Canal de São Sebastião - Rede Costeira
# 3      Canal de São Sebastião - Rede Costeira
# 4      Canal de São Sebastião - Rede Costeira
# ...                                       ...
# 67078  Canal de São Sebastião - Rede Costeira
# 67079  Canal de São Sebastião - Rede Costeira
# 67080  Canal de São Sebastião - Rede Costeira
# 67081  Canal de São Sebastião - Rede Costeira
# 67082  Canal de São Sebastião - Rede Costeira
#
# [1248 rows x 9 columns]

# %%
## agora selecionamos os dados em superficie - SSRC 11011, 11021, 11031, 11041, 11051 - 
ccs_chla = ccs_wq.loc[ccs_wq['Parametro']== 'Clorofila-a']

# %%
ccs_chla
# Out:
#            Ponto             lat            lon       Data      Hora  \
# 7      SSRC11031   23°49'16.31"S   45°24'9.09"O 2019-02-12  11:30:00
# 3895   SSRC11031   23°49'16.31"S   45°24'9.09"O 2019-08-20  10:06:00
# 8297   SSRC11031   23°49'16.31"S   45°24'9.09"O 2020-02-12  09:52:00
# 11482  SSRC11031   23°49'16.31"S   45°24'9.09"O 2021-05-18  08:59:00
# 16594  SSRC11031   23°49'16.31"S   45°24'9.09"O 2013-05-07  10:34:00
# 19891  SSRC11031   23°49'16.31"S   45°24'9.09"O 2013-09-24  10:53:00
# 24029  SSRC11031   23°49'16.31"S   45°24'9.09"O 2016-05-10  09:46:00
# 27228  SSRC11031   23°49'16.31"S   45°24'9.09"O 2016-09-13  09:51:00
# 29235  SSRC11031   23°49'16.31"S   45°24'9.09"O 2017-04-18  10:03:00
# 32861  SSRC11031   23°49'16.31"S   45°24'9.09"O 2017-09-12  10:04:00
# 34446  SSRC11031   23°49'16.31"S   45°24'9.09"O 2018-04-17  10:15:00
# 39986  SSRC11031   23°49'16.31"S   45°24'9.09"O 2018-09-12  11:07:00
# 42357  SSRC11031   23°49'16.31"S   45°24'9.09"O 2010-02-24  13:16:00
# 44684  SSRC11031   23°49'16.31"S   45°24'9.09"O 2010-08-31  14:15:00
# 47056  SSRC11031   23°49'16.31"S   45°24'9.09"O 2011-04-26  13:21:00
# 50240  SSRC11031   23°49'16.31"S   45°24'9.09"O 2011-10-25  13:10:00
# 51915  SSRC11031   23°49'16.31"S   45°24'9.09"O 2012-04-10  15:04:00
# 54918  SSRC11031   23°49'16.31"S   45°24'9.09"O 2012-08-28  16:53:00
# 57289  SSRC11031   23°49'16.31"S   45°24'9.09"O 2014-05-20  11:21:00
# 61126  SSRC11031   23°49'16.31"S   45°24'9.09"O 2014-10-28  10:07:00
# 63608  SSRC11031   23°49'16.31"S   45°24'9.09"O 2015-05-13  09:37:00
# 67056  SSRC11031   23°49'16.31"S   45°24'9.09"O 2015-09-22  10:23:00
#
#          Parametro  valor unidade                                   local
# 7      Clorofila-a   0.56    µg/L  Canal de São Sebastião - Rede Costeira
# 3895   Clorofila-a   2.29    µg/L  Canal de São Sebastião - Rede Costeira
# 8297   Clorofila-a   0.80    µg/L  Canal de São Sebastião - Rede Costeira
# 11482  Clorofila-a   0.80    µg/L  Canal de São Sebastião - Rede Costeira
# 16594  Clorofila-a   0.61    µg/L  Canal de São Sebastião - Rede Costeira
# 19891  Clorofila-a   1.34    µg/L  Canal de São Sebastião - Rede Costeira
# 24029  Clorofila-a   1.07    µg/L  Canal de São Sebastião - Rede Costeira
# 27228  Clorofila-a   1.78    µg/L  Canal de São Sebastião - Rede Costeira
# 29235  Clorofila-a   1.69    µg/L  Canal de São Sebastião - Rede Costeira
# 32861  Clorofila-a   0.56    µg/L  Canal de São Sebastião - Rede Costeira
# 34446  Clorofila-a   2.94    µg/L  Canal de São Sebastião - Rede Costeira
# 39986  Clorofila-a   1.92    µg/L  Canal de São Sebastião - Rede Costeira
# 42357  Clorofila-a   0.01    µg/L  Canal de São Sebastião - Rede Costeira
# 44684  Clorofila-a   0.25    µg/L  Canal de São Sebastião - Rede Costeira
# 47056  Clorofila-a   0.97    µg/L  Canal de São Sebastião - Rede Costeira
# 50240  Clorofila-a   3.67    µg/L  Canal de São Sebastião - Rede Costeira
# 51915  Clorofila-a   1.16    µg/L  Canal de São Sebastião - Rede Costeira
# 54918  Clorofila-a   1.41    µg/L  Canal de São Sebastião - Rede Costeira
# 57289  Clorofila-a   1.10    µg/L  Canal de São Sebastião - Rede Costeira
# 61126  Clorofila-a   0.56    µg/L  Canal de São Sebastião - Rede Costeira
# 63608  Clorofila-a   1.73    µg/L  Canal de São Sebastião - Rede Costeira
# 67056  Clorofila-a   0.56    µg/L  Canal de São Sebastião - Rede Costeira

# %%
len(ccs_chla)
# Out:
# 22
